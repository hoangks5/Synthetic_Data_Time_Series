# %%
import pandas as pd

# %%
data_new = pd.read_csv('1.csv')

# %%
data_new.plot.line(x='datetime')
# Out:
# <AxesSubplot: xlabel='datetime'>

# %%
import random
nb = random.randint(0,46000)
s = data_new[nb:nb+100]
s.plot.line(x='Date',y='Open')
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
s.to_csv('./data/data('+str(random.randint(1,10000))+').csv',index=False)
