# %%
import pandas as pd

# %%
data_new = pd.read_csv('yahoo_stock.csv')

# %%
data_new.plot.line(x='Date',y='')
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
import random
nb = random.randint(0,10000)
s = data_new[nb:nb+300]
s.plot.line(x='Date')
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
s.to_csv('./data/data('+str(random.randint(1,10000))+').csv',index=False)
