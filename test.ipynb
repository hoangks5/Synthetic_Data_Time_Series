# %%
import pandas as pd

# %%
data_new = pd.read_csv('gamer1-ppg-2000-01-01.csv')

# %%
data_new.plot.line(x='Time')
# Out:
# <AxesSubplot: xlabel='datetime'>

# %%
import random
nb = random.randint(0,46000)
s = data_new[nb:nb+200]
s.plot.line(x='datetime')
# Out:
# <AxesSubplot: xlabel='datetime'>

# %%
s.to_csv('./data/data('+str(random.randint(1,10000))+').csv',index=False)
