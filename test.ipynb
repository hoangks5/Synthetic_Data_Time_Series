# %%
import pandas as pd

# %%
data_new = pd.read_csv('Miles_Traveled.csv')

# %%
''' import random
nb = random.randint(0,500000)
s = data_new[nb:nb+1000] '''
data_new.plot.line(x='date')
# Out:
# <AxesSubplot: xlabel='date'>
