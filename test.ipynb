# %%
import pandas as pd

# %%
data_new = pd.read_csv('ts_data.csv',sep=',')
data_new.to_csv('1.csv')

# %%
data_new.plot.line(x='time')
# Out:
# <AxesSubplot: xlabel='time'>

# %%
import random
nb = random.randint(0,1000000)
s = data_new[nb:nb+500]
s.plot.line(x='time',y = 'y')
# Out:
# <AxesSubplot: xlabel='time'>

# %%
s.to_csv('./data/data('+str(random.randint(1,10000))+').csv',index=False)
