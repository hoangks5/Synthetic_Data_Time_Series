# %%
import pandas as pd

# %%
data_new = pd.read_csv('Amazon.csv')

# %%
data_new.plot.line(x='Date',y='High')
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
import random
nb = random.randint(0,5500)
s = data_new[nb:nb+300]
s.plot.line(x='Date',y='Volume')
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
s.to_csv('./data/data('+str(random.randint(1,10000))+').csv',index=False)
