# %%
import pandas as pd

# %%
data = pd.read_csv('test.csv')
data
# Out:
#          user  activity       timestamp  x-axis  y-axis    z-axis
# 0           1   Walking   4991922345000    0.69   10.80 -2.030000
# 1           1   Walking   4991972333000    6.85    7.44 -0.500000
# 2           1   Walking   4992022351000    0.93    5.63 -0.500000
# 3           1   Walking   4992072339000   -2.11    5.01 -0.690000
# 4           1   Walking   4992122358000   -4.59    4.29 -1.950000
# ...       ...       ...             ...     ...     ...       ...
# 1073618    36  Standing  15049012250000   -0.91    9.43  2.533385
# 1073619    36  Standing  15049062268000   -1.18    9.51  2.492524
# 1073620    36  Standing  15049112287000   -1.50    9.53  2.533385
# 1073621    36  Standing  15049162275000   -2.07    8.77  2.179256
# 1073622    36  Standing  15049212262000   -2.14    9.89  3.255263
#
# [1073623 rows x 6 columns]

# %%
for i in range(1,37):
    data_new = data.loc[data['user'] == i]
    data_new.to_csv('data('+str(i)+').csv',index=False)

# %%
for i in range(1,2):
    with open('data('+str(i)+').csv','r',encoding='utf-8') as f:
        data = f.read().splitlines()
    data_new = []
    for i in range(len(data)):
        if i%3 == 0:
            data_new.append(data[i])
    sss = '\n'.join(data_new)
    sss.to_csv('datanew.csv')
# Out:
# ['user,activity,timestamp,x-axis,y-axis,z-axis', '1,Walking,4992022351000,0.93,5.63,-0.5', '1,Walking,4992172376000,12.41,11.18,7.82', '1,Walking,4992322339000,-2.68,15.89,-0.38', '1,Walking,4992472333000,4.02,9.81,-1.61', '1,Walking,4992622327000,3.34,7.31,-0.42', '1,Walking,4992772321000,8.43,10.76,1.14', '1,Walking,4992922345000,2.49,17.86,-2.83', '1,Walking,4993072339000,7.16,3.57,-0.72', '1,Walking,4993222333000,-3.17,7.74,4.71', '1,Walking,4993372327000,0.15,16.13,-2.83', '1,Walking,4993522321000,3.49,10.57,-1.33', '1,Walking,4993692334000,2.07,8.12,-2.3', '1,Walking,4993842298000,10.92,11.11,2.91', '1,Walking,4993992292000,2.91,15.64,-4.21', '1,Walking,4994142316000,0.99,3.95,-1.5', '1,Walking,4994292341000,10.61,10.57,10.88', '1,Walking,4994442304000,-3.17,11.14,-3.79', '1,Walking,4994592298000,5.6,9.08,-1.84', '1,Walking,4994742292000,3.15,8.16,-0.72', '1,Walking,4994892377000,11.6,12.6,6.66', '1,Walking,4995042310000,1.95,19.23,-5.01', '1,Walking,4995192304000,2.15,3.06,-0.99', '1,Walking,4995342328000,12.91,13.99,9.77', '1,Walking,4995492322000,-3.34,12.72,-7.04', '1,Walking,4995642347000,6.02,7.74,-0.46', '1,Walking,4995792341000,1.14,9.11,-1.8', '1,Walking,4995942426000,12.11,10.73,2.03', '1,Walking,4996092298000,1.18,18.62,-5.71', '1,Walking,4996242292000,-0.19,2.37,-1.76', '1,Walking,4996392316000,19.57,17.05,1.33', '1,Walking,4996542310000,-2.68,9.43,-4.44', '1,Walking,4996692304000,5.05,7.06,-0.46', '1,Walking,4996842298000,3.53,8.73,-1.18', '1,Walking,4996992322000,12.57,10.65,3.87', '1,Walking,4997142347000,-0.11,15.02,-5.94', '1,Walking,4997292341000,-2.83,2.79,-3.02', '1,Walking,4997442334000,19.04,16.02,3.11', '1,Walking,4997592298000,-3.26,8.28,-2.83', '1,Walking,4997742292000,9.08,6.63,1.33', '1,Walking,4997892316000,2.18,9.23,-1.65', '1,Walking,4998042341000,11.5,11.18,5.22', '1,Walking,4998192304000,-0.27,18.35,-7.46', '1,Walking,4998342298000,0.95,2.72,-1.33', '1,Walking,4998492322000,19.53,17.01,1.27', '1,Walking,4998592298000,-0.99,15.75,-1.23', '1,Walking,4998752362000,3.53,9.11,-1.53', '1,Walking,4998902356000,3.57,7.67,0.11', '1,Walking,4999052350000,9.7,10.8,0.15', '1,Walking,4999202344000,2.76,19.11,-4.4', '1,Walking,4999352369000,2.68,2.37,-1.14', '1,Walking,4999502362000,17.35,15.66,5.01', '1,Walking,4999652356000,-3.21,8.39,-4.71', '1,Walking,4999802350000,4.67,7.97,-1.99', '1,Walking,4999952375000,3.21,10.69,1.31', '1,Walking,5000102369000,14.02,11.41,5.13', '1,Walking,5000252332000,-1.5,16.7,-9.15', '1,Walking,5000402356000,-0.99,1.84,-2.11', '1,Walking,5000552381000,16.63,12.76,3.83', '1,Walking,5000702375000,-2.49,10.42,-1.88', '1,Walking,5000852369000,6.02,6.74,-1.53', '1,Walking,5001062177000,9.19,10.08,-0.08', '1,Walking,5001162427000,8.01,11.14,1.46', '1,Walking,5001322339000,-0.89,9.51,-4.1', '1,Walking,5001472333000,-5.41,3.68,-3.87', '1,Walking,5001622327000,7.27,5.67,-3.26', '1,Walking,5001772321000,-0.61,10.0,-0.27', '1,Walking,5001922345000,6.17,6.13,-1.65', '1,Walking,5002072370000,6.09,11.88,1.18', '1,Walking,5002222333000,7.16,14.18,-1.5', '1,Walking,5002372358000,-0.15,6.7,-0.91', '1,Walking,5002522321000,-6.7,4.4,-3.83', '1,Walking,5002672345000,5.05,7.4,-5.82', '1,Walking,5002822339000,0.95,11.65,-1.95', '1,Walking,5002972333000,5.24,5.86,-0.8', '1,Walking,5003122327000,6.7,11.45,-0.72', '1,Walking,5003272321000,6.82,14.37,0.61', '1,Walking,5003422345000,0.89,5.6,-0.15', '1,Walking,5003572370000,-5.94,1.73,-2.14', '1,Walking,5003722333000,7.5,6.4,0.11', '1,Walking,5003872358000,-0.53,9.62,-2.75', '1,Walking,5004022321000,5.01,5.83,-0.57', '1,Walking,5004172345000,8.35,11.37,-0.34', '1,Walking,5004322339000,7.01,12.91,0.53', '1,Walking,5004472333000,1.12,7.01,-0.5', '1,Walking,5004622327000,-8.96,2.53,-4.06', '1,Walking,5004772321000,3.64,14.9,0.93', '1,Walking,5004922376000,0.95,10.73,-1.65', '1,Walking,5005072339000,5.71,5.98,-1.99', '1,Walking,5005222333000,9.43,9.92,0.76', '1,Walking,5005382337000,4.71,18.54,-3.34', '1,Walking,5005532331000,1.04,2.49,-1.42', '1,Walkin ...

# %%
data_new = data.loc[data['user'] == i]

# %%
data_new.drop(index=[0, 1])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [63], line 1
# ----> 1 data_new.drop(index=[0, 1])
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/frame.py:5391, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5243 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5244 def drop(  # type: ignore[override]
#    5245     self,
#    (...)
#    5252     errors: IgnoreRaise = "raise",
#    5253 ) -> DataFrame | None:
#    5254     """
#    5255     Drop specified labels from rows or columns.
#    5256
#    (...)
#    5389             weight  1.0     0.8
#    5390     """
# -> 5391     return super().drop(
#    5392         labels=labels,
#    5393         axis=axis,
#    5394         index=index,
#    5395         columns=columns,
#    5396         level=level,
#    5397         inplace=inplace,
#    5398         errors=errors,
#    5399     )
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/util/_decorators.py:317, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     311 if len(args) > num_allow_args:
#     312     warnings.warn(
#     313         msg.format(arguments=arguments),
#     314         FutureWarning,
#     315         stacklevel=find_stack_level(inspect.currentframe()),
#     316     )
# --> 317 return func(*args, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:4510, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4508 for axis, labels in axes.items():
#    4509     if labels is not None:
# -> 4510         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4512 if inplace:
#    4513     self._update_inplace(obj)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/generic.py:4551, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4549         new_axis = axis.drop(labels, level=level, errors=errors)
#    4550     else:
# -> 4551         new_axis = axis.drop(labels, errors=errors)
#    4552     indexer = axis.get_indexer(new_axis)
#    4554 # Case for non-unique axis
#    4555 else:
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/pandas/core/indexes/base.py:6972, in Index.drop(self, labels, errors)
#    6970 if mask.any():
#    6971     if errors != "ignore":
# -> 6972         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6973     indexer = indexer[~mask]
#    6974 return self.delete(indexer)
#
# KeyError: '[0, 1] not found in axis'

# %%
data_new
# Out:
#          user  activity       timestamp  x-axis  y-axis    z-axis
# 1041515    36   Walking  13059342298000   -2.87   10.46  0.231546
# 1041516    36   Walking  13059392255000   -1.76   10.04 -0.531194
# 1041517    36   Walking  13059442243000   -1.80   10.12 -1.035146
# 1041518    36   Walking  13059492261000   -1.73   10.19 -0.422231
# 1041519    36   Walking  13059542249000   -2.07    9.81 -1.035146
# ...       ...       ...             ...     ...     ...       ...
# 1073618    36  Standing  15049012250000   -0.91    9.43  2.533385
# 1073619    36  Standing  15049062268000   -1.18    9.51  2.492524
# 1073620    36  Standing  15049112287000   -1.50    9.53  2.533385
# 1073621    36  Standing  15049162275000   -2.07    8.77  2.179256
# 1073622    36  Standing  15049212262000   -2.14    9.89  3.255263
#
# [32108 rows x 6 columns]

# %%
data_new.plot.line(x='timestamp')
# Out:
# <AxesSubplot: xlabel='timestamp'>
