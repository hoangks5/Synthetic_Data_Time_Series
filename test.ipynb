# %%
import pandas as pd

# %%
data_new = pd.read_csv('Alcohol_Sales.csv')

# %%
''' import random
nb = random.randint(0,500000)
s = data_new[nb:nb+1000] '''
data_new.plot.line(x='DATE')
# Out:
# <AxesSubplot: xlabel='time'>

# %%
s.to_csv('test('+str(random.randint(1,10000))+').csv',index=False)
