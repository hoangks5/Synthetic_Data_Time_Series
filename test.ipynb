# %%
import pandas as pd

# %%
data = pd.read_csv('./TimeSeries.csv')
data.to_csv('test.csv')

# %%
data_new = pd.read_csv('test.csv')

# %%
import random
nb = random.randint(0,500000)
s = data_new[nb:nb+10000]
s.plot.line(x='timestamp')
# Out:
# <AxesSubplot: xlabel='timestamp'>

# %%
s.to_csv('test.csv')
