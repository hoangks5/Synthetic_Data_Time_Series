# %%
import pandas as pd

# %%
data_new = pd.read_csv('1.csv',sep=';')

# %%
data_new.plot.line(x='Timestamp')
# Out:
# <AxesSubplot: xlabel='Timestamp'>

# %%
import random
nb = random.randint(0,60000)
s = data_new[nb:nb+4000]
s.plot.line(x='Time')
# Out:
# <AxesSubplot: xlabel='Time'>

# %%
s.to_csv('./data/data('+str(random.randint(1,10000))+').csv',index=False)
